# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/sanfrancisco-salary-3-years/SanFrancisco_salary (excel).xlsx
# /kaggle/input/sanfrancisco-salary-3-years/SanFrancisco_salary (csv).csv

# %% [markdown]
# # Class 11 - Your Name
# **Date:** 2024-5-29
# **Title:** Analysis of Employee Salaries
# **Description:** This dataset includes information on the salaries of San Francisco city employees.

# %% [markdown]
# # Display the first 5 rows in the dataset

# %%
import pandas as pd

df = pd.read_csv('/kaggle/input/sanfrancisco-salary-3-years/SanFrancisco_salary (csv).csv')
df.head()
# Out:
#    Unnamed: 0     Id        EmployeeName                      JobTitle  \
# 0       36159  36160      Gary Altenberg  Lieutenant, Fire Suppression
# 1       36160  36161        Gregory Suhr               Chief of Police
# 2       36161  36162          Khoa Trinh   Electronic Maintenance Tech
# 3       36162  36163  Joanne Hayes-White        Chief, Fire Department
# 4       36163  36164   Frederick Binkley     EMT/Paramedic/Firefighter
#
#      BasePay  OvertimePay  OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  128808.87    220909.48  13126.31  44430.12  362844.66         407274.78
# 1  302578.00         0.00  18974.11  69810.19  321552.11         391362.30
# 2  111921.00    146415.32  78057.41  53102.29  336393.73         389496.02
# 3  296943.01         0.00  17816.59  72047.88  314759.60         386807.48
# 4  126863.19    192424.49  17917.18  44438.25  337204.86         381643.11
#
#    Year Department  Department_ML
# 0  2012       Fire              4
# ...

# %% [markdown]
# # Display rows from row 40 to 50

# %%
df.iloc[40:51]
# Out:
#     Unnamed: 0     Id       EmployeeName                        JobTitle  \
# 40       36199  36200     Scott Scholzen                     Firefighter
# 41       36200  36201     Ai Kyung Chung                     Anesthetist
# 42       36201  36202        Pete Fay Jr  Battlion Chief, Fire Suppressi
# 43       36202  36203       John Ehrlich                       Captain 3
# 44       36203  36204         Venus Azar               Asst Med Examiner
# 45       36204  36205     Denise Schmitt                  Deputy Chief 3
# 46       36205  36206          Jay Huish                     Dept Head V
# 47       36206  36207  Gregory Stangland       EMT/Paramedic/Firefighter
# 48       36207  36208      Arthur Kenney    Asst Chf of Dept (Fire Dept)
# 49       36208  36209       Kevin Taylor  Battlion Chief, Fire Suppressi
# 50       36209  36210      Robert Postel    Asst Chf of Dept (Fire Dept)
#
#       BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# ...

# %% [markdown]
# # Find the job title of the highest paid salary (TotalPay)

# %%
highest_paid = df[df['TotalPay'] == df['TotalPay'].max()]
highest_paid['JobTitle']
# Out:
# 73763    Deputy Chief 3
# Name: JobTitle, dtype: object

# %% [markdown]
# [](http://)# Find the average BasePay of Executive Contract Employee (JobTitle)

# %%
average_basepay = df[df['JobTitle'] == 'Executive Contract Employee']['BasePay'].mean()
average_basepay
# Out:
# 259328.45833333334

# %% [markdown]
# # Find the sum of OvertimePay for each job title

# %%
overtime_sum = df.groupby('JobTitle')['OvertimePay'].sum()

overtime_sum
# Out:
# JobTitle
# ACPO,JuvP, Juv Prob (SFERS)            0.000000
# ASR Senior Office Specialist       24659.310054
# ASR-Office Assistant                 758.610000
# Account Clerk                      51364.299987
# Accountant I                           0.000000
#                                       ...
# Wire Rope Cable Maint Sprv        247340.770000
# Worker's Comp Supervisor 1             0.000000
# Worker's Compensation Adjuster         0.000000
# X-Ray Laboratory Aide             348376.709852
# Youth Comm Advisor                     0.000000
# Name: OvertimePay, Length: 1109, dtype: float64

# %% [markdown]
# # Which job title have spend more for OvertimePay (optional)

# %%
overtime_sum = df.groupby('JobTitle')['OvertimePay'].sum()

job_title_max_overtime = overtime_sum.idxmax()

job_title_max_overtime
# Out:
# 'Transit Operator'

# %% [markdown]
# # What is the most common and the least common job in this dataset

# %%
susan_currin_job = df[df['EmployeeName'] == 'Susan Currin']['JobTitle']
susan_currin_job
# Out:
# 29       Adm, SFGH Medical Center
# 73789    Adm, SFGH Medical Center
# Name: JobTitle, dtype: object

# %% [markdown]
# # What is the job title for Susan Currin

# %%
# Filter the DataFrame for Susan Currin and retrieve her job title(s)
susan_currin_job = df.loc[df['EmployeeName'] == 'Susan Currin', 'JobTitle'].unique()

# Display the result
susan_currin_job
# Out:
# array(['Adm, SFGH Medical Center'], dtype=object)

# %% [markdown]
# # Find the mean , standard deviation and the median for TotalPay in this dataset

# %%
mean_totalpay = df['TotalPay'].mean()
mean_totalpay
# Out:
# 76130.13223246128

# %%
std_totalpay = df['TotalPay'].std()
std_totalpay,
# Out:
# (51269.83938559982,)

# %%
median_totalpay = df['TotalPay'].median()
median_totalpay
# Out:
# 72630.7

# %% [markdown]
# # How many standard deviation does Captain, Fire Suppression highest salary (TotalPay) deviate from the mean
#
# hint : z index

# %%
deviation_from_mean = (highest_totalpay_captain - mean_totalpay) / std_totalpay
deviation_from_mean
# Out:
# 4.535603983827814

# %% [markdown]
# # What is the highest BasePay in the dataset?

# %%
highest_basepay = df['BasePay'].max()
highest_basepay
# Out:
# 319275.01

# %% [markdown]
# # How many unique job titles are there in the dataset?

# %%
unique_job_titles = df['JobTitle'].nunique()
unique_job_titles
# Out:
# 1109

# %% [markdown]
# # What is the average TotalPay for employees with the job title 'Police Officer'?

# %%
average_totalpay_police_officer = df[df['JobTitle'] == 'Police Officer']['TotalPay'].mean()
average_totalpay_police_officer
# Out:
# 96670.31978216473
